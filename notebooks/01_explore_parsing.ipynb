# %% [markdown]
# # 01 — Explore Resume Parsing
#
# Scratchpad notebook for trying out parsers and extractors on real resumes.
# Drop sample files into `../data/resumes/` and iterate here.

# %%
import sys
sys.path.insert(0, '..')

from src.parser import parse_resume
from src.features import extract_features

# %%
# resume_path = '../data/resumes/sample.pdf'
# text = parse_resume(resume_path)
# profile = extract_features(text)
# profile
